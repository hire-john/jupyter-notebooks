# %% [markdown]
# # ***Discussion 1.2:*** *Finding the roots of a quadratic function using the quadratic formula*

# %% [markdown]
# Author: *John McDonnell*

# %% [markdown]
# For part of my University studies for week one of Calculus we were tasked to revisit pre-calculus material as sort of a refresher prior to studying limits and derivatives in depth. For these discussions, we can select one of the numerous topics, and as noted in the title I selected *finding the roots of a quadratic function using the quadratic formula*. We were giving additional instructions as follows:
#
# * Choose a topic you will be using. Do not repeat a topic that has already been chosen! To be sure you and a fellow classmate aren't going to work on the same topic at the same time, call “dibs” on a problem with a post on the forum; but you must post your original response to that thread within 24 hours, or you lose your "dibs" and you may have to choose a new topic.
# * Find a resource with a tutorial/ information that will help you create a specific, original, math problem related to your topic.  Remember, you are NOT teaching the whole topic, but just how to solve ONE PROBLEM you've created.  You must cite your source in APA format.  (Even if you know how to create and solve a problem related to your topic, you still must include a source that your classmates can reference, to read more about what you are teaching.)
# * Tell us the problem you've created.  Remember, your problem must be ORIGINAL, made up by YOU. DO NOT use a problem that has a full solution from a resource.
# * Tell us how to solve your problem step-by-step.  Your solution should include all mathematical steps as well as explanations in your own words.  You can type this with the equation editor in the reply box, use an image file to show hand-written work, or make a video using the media tool to provide your explanations!  I encourage you to get creative with how you explain your solution!

# %% [markdown]
# I have followed the instructions for the original discussion post as submitted and forgone and indepth analysis and regurgitation of the subject matter, however I have done so here. Here I have decided for multiple reasons to elaborate on the topic entirely. Included is also snippets from a MathCAD file which demonstrates and illustrates what is covered here as well. There' are also my thoughts and opinions on the topic throughout.

# %% [markdown]
# Before we dive into the topic of discussion I felt it important to breakdown what the problem means exactly. I will cover what each part of the topic means:

# %% [markdown]
# ### Quadratic
#
# Truthfully, I understand the reasoning behind calling a function a quadratic function but don't necessarily agree with it. The idea being our function is composed of a quadratic equation and the reasoning a quadratic equation is called a quadratic or representation of four is due to the squaring operation of the term raised to the second power. Squaring operations were apparently derived from squares and calculating the area by multiplying the two dimensions length x width. Personally, I feel like this non-direct depth of meaning is why students struggle to understand and remember mathematical concepts. You can see this in the idea of a third power term being a Cubic Equation or Function.
#
# Mathematically there are other purposes that don't directly translate to geometric shapes. I personally think it would make math easier to understand if we simply followed a standard of naming functions and equations by their exponent. For instance:
#
#     1. ax^1 + bx + c = 0: Unitary-Exponent General-Form Equation
#     2. ax^2 + bx + c = 0: Secondary-Exponent General-Form Equation
#     3. ax^3 + bx + c = 0: Tertiary-Exponent General-Form Equation
#
# It's more verbose, however, it's easier to form a short-hand code for as well as derive much more valuable information from. A quadratic equation might come in numerous forms and contain any number of terms. Thus, we could further standardize mathematical nomenclature by doing something like the above list indicating the form the equation is in if any standardized form is present if not, we could simply rewrite it as follows:
#
#     * x^3 + 2ac - 3x + 1: Teritiary-Exponent Quaternary-Term Equation with short-hand code such as 3E-4T
#
# Also, If the above is in the proposed standardized form we could thus code it as so:c
#
#     * x^3 + 2ac - 3x + 1 = 0: Teritiary-Exponent Quaternary-Term Equation in General Form with short-hand code such as 3E-4T-1 with the 001 being a standardized identifier assigned to each known mathematical form with for instance slope-intercept being 2 and point-slope form being 3 and so on.

# %% [markdown]
# Thus, we could easily code in more classification of mathematical properties and further derive value as follows:

# %%
x = 5
equation = 4**3 + 2 * x + 1
classification = "3E-4T-1"

if(classification == "3E-4T-1"):
    # do something like solve based on the information
    # or automatically classify 
    # you could even parse the equation and  generate the classification
    print("Teritiary-Exponent Quaternary-Term Equation in General Form SCREECH IS AWESOME")
else:
    print("Unknown equation")
# Out:
# Teritiary-Exponent Quaternary-Term Equation in General Form SCREECH IS AWESOME

# %% [markdown]
# ### Roots
#
# Roots are the points such as (2, 0) or where the output or Y-axis value of the Quadratic Function is equal to zero or where our graph intersects the Y-axis.

# %% [markdown]
# ### How to Solve for Roots of Quadratic Functions / Equations

# %% [markdown]
# ![mcdonnell_discussion_1_2_solving.png](attachment:983ae756-046d-432a-b775-9fdb2a3a2497.png)

# %% [markdown]
# ## Tutorial / Source / Reference
#
# Owlcation.com. (2022, July 22). How to find the Roots of a Quadratic Function.
# > https://owlcation.com/stem/How-to-Find-the-Roots-of-A-Quadratic-Function
